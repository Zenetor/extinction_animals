# %%
import numpy as np
import pandas as pd
import matplotlib as mp

vertebrates = pd.read_csv("Allvertebrates.csv")
vertebrates.head()
# Out:
#    Internal taxon ID           Class              Order          Family  \
# 0               1078  ACTINOPTERYGII        PERCIFORMES   CENTRARCHIDAE
# 1              11060  ACTINOPTERYGII        PERCIFORMES       KUHLIIDAE
# 2              11150  ACTINOPTERYGII  TETRAODONTIFORMES  TETRAODONTIDAE
# 3              12137  ACTINOPTERYGII        PERCIFORMES        SPARIDAE
# 4              12416  ACTINOPTERYGII        PERCIFORMES      LUTJANIDAE
#
#           Genus       Species Red List threat category Population trend  \
# 0   Ambloplites     cavifrons            Least Concern           Stable
# 1        Kuhlia     marginata            Least Concern           Stable
# 2  Lagocephalus       gloveri           Data Deficient       Decreasing
# 3  Lithognathus  lithognathus               Endangered       Decreasing
# 4      Lutjanus        analis          Near Threatened       Decreasing
#
#                               Systems                             Realms  \
# ...

# %%
vertebrates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46557 entries, 0 to 46556
# Data columns (total 13 columns):
# Internal taxon ID           46557 non-null int64
# Class                       46557 non-null object
# Order                       46557 non-null object
# Family                      46557 non-null object
# Genus                       46557 non-null object
# Species                     46557 non-null object
# Red List threat category    46557 non-null object
# Population trend            45510 non-null object
# Systems                     46557 non-null object
# Realms                      41141 non-null object
# Habitats list               46557 non-null object
# Threats list                46557 non-null object
# Threats                     38414 non-null object
# dtypes: int64(1), object(12)
# memory usage: 4.6+ MB

# %%
RLTC_or = vertebrates["Red List threat category"].value_counts()
#RLTC_or
RLTC_or = pd.DataFrame(RLTC_or)
RLTC_or
RLTC_6top = RLTC_or.head(6).copy()
RLTC_others = RLTC_or(data ={'Red List threat category' : ['Others'],
                                       'value' : [RLTC_or['dftype'][6:].sum()]
                                      })
#RLTC_improved = pd.concat([RTLC_6top, RLTC_others])
#RLTC_improved
#RLTC_or.plot(kind='pie')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dftype'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-94869eb2c39f> in <module>
#       5 RLTC_6top = RLTC_or.head(6).copy()
# ...
